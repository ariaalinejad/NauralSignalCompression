# %%
import numpy as np
import matplotlib.pyplot as plt 
s0 = np.load('../test_data_sintef.npy') # 48kHz (Dataset 1)
s1 = np.load('../52728_2021-09-25_01_24KHz_test_data_sintef.npy') # 24kHz (Dataset 2)
s2 = np.load('../56180_2021-11-05_06_24KHz_test_data_sintef.npy') # 24kHz (Dataset 3)
s3 = np.load('../61467_2022-09-16_01_48KHz_test_data_sintef.npy') # 48kHz (Dataset 4)

# %%
ts0 = np.linspace(0,10, int(s0.shape[0])) # time 
'''
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='all', sharex=True)
for j in range(3):
    for i in range(4):
        axs[i, j].plot(ts0, s0[:,j*4+i], color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('seconds [s]')
plt.suptitle('LFP/AP channels', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
axs[0,0].plot(ts0, s0[:,12], color='#3B7DA6')
axs[1,0].plot(ts0, s0[:,13], color='#3B7DA6')
axs[0,0].set_title('EcoG', fontsize=16)
axs[1,0].set_xlabel('seconds [s]')
axs[0,1].plot(ts0, s0[:,14], color='#3B7DA6')
axs[1,1].plot(ts0, s0[:,15], color='#3B7DA6')
axs[0,1].set_title('EMG', fontsize=16)
axs[1,1].set_xlabel('seconds [s]')
plt.tight_layout() 
plt.show()

# plot the frequency components
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s0[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s0[:,j*4+i]), ts0[1] - ts0[0])

        axs[i, j].semilogx(freqs, P, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Power Spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s0[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s0[:,j*4+i]), ts0[1] - ts0[0])
    axs.T.flatten()[i].semilogx(freqs, P, color='#3B7DA6')
axs[0,0].set_title('Power Spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Power Spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()'''

# log scale 
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s0[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s0[:,j*4+i]), ts0[1] - ts0[0])

        axs[i, j].semilogx(freqs, P_db, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Log scale power spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s0[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s0[:,j*4+i]), ts0[1] - ts0[0])
    axs.T.flatten()[i].semilogx(freqs, P_db, color='#3B7DA6')
axs[0,0].set_title('Log scale power spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Log scale power spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()

# %%
# Visualize the signals
ts1 = np.linspace(0,10, int(s1.shape[0])) # time 
'''
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='all', sharex=True)
for j in range(3):
    for i in range(4):
        axs[i, j].plot(ts1, s1[:,j*4+i], color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('seconds [s]')
plt.suptitle('LFP/AP channels', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
axs[0,0].plot(ts1, s1[:,12], color='#3B7DA6')
axs[1,0].plot(ts1, s1[:,13], color='#3B7DA6')
axs[0,0].set_title('EcoG', fontsize=16)
axs[1,0].set_xlabel('seconds [s]')
axs[0,1].plot(ts1, s1[:,14], color='#3B7DA6')
axs[1,1].plot(ts1, s1[:,15], color='#3B7DA6')
axs[0,1].set_title('EMG', fontsize=16)
axs[1,1].set_xlabel('seconds [s]')
plt.tight_layout() 
plt.show()

# plot the frequency components
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s1[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s1[:,j*4+i]), ts1[1] - ts1[0])

        axs[i, j].semilogx(freqs, P, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Power Spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s1[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s1[:,j*4+i]), ts1[1] - ts1[0])
    axs.T.flatten()[i].semilogx(freqs, P, color='#3B7DA6')
axs[0,0].set_title('Power Spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Power Spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()'''

# log scale 
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s1[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s1[:,j*4+i]), ts1[1] - ts1[0])

        axs[i, j].semilogx(freqs, P_db, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Log scale power spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s1[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s1[:,j*4+i]), ts1[1] - ts1[0])
    axs.T.flatten()[i].semilogx(freqs, P_db, color='#3B7DA6')
axs[0,0].set_title('Log scale power spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Log scale power spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()

# %%
# Visualize the signals
ts2 = np.linspace(0,10, int(s2.shape[0])) # time 
'''
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='all', sharex=True)
for j in range(3):
    for i in range(4):
        axs[i, j].plot(ts2, s2[:,j*4+i], color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('seconds [s]')
plt.suptitle('LFP/AP channels', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
axs[0,0].plot(ts2, s2[:,12], color='#3B7DA6')
axs[1,0].plot(ts2, s2[:,13], color='#3B7DA6')
axs[0,0].set_title('EcoG', fontsize=16)
axs[1,0].set_xlabel('seconds [s]')
axs[0,1].plot(ts2, s2[:,14], color='#3B7DA6')
axs[1,1].plot(ts2, s2[:,15], color='#3B7DA6')
axs[0,1].set_title('EMG', fontsize=16)
axs[1,1].set_xlabel('seconds [s]')
plt.tight_layout() 
plt.show()

# plot the frequency components
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s2[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s2[:,j*4+i]), ts2[1] - ts2[0])

        axs[i, j].semilogx(freqs, P, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Power Spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s2[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s2[:,j*4+i]), ts2[1] - ts2[0])
    axs.T.flatten()[i].semilogx(freqs, P, color='#3B7DA6')
axs[0,0].set_title('Power Spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Power Spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()'''

# log scale 
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s2[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s2[:,j*4+i]), ts2[1] - ts2[0])

        axs[i, j].semilogx(freqs, P_db, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Log scale power spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s2[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s2[:,j*4+i]), ts2[1] - ts2[0])
    axs.T.flatten()[i].semilogx(freqs, P_db, color='#3B7DA6')
axs[0,0].set_title('Log scale power spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Log scale power spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()

# %%
# Visualize the signals
ts3 = np.linspace(0,10, int(s3.shape[0])) # time 
'''
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='all', sharex=True)
for j in range(3):
    for i in range(4):
        axs[i, j].plot(ts3, s3[:,j*4+i], color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('seconds [s]')
plt.suptitle('LFP/AP channels', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
axs[0,0].plot(ts3, s3[:,12], color='#3B7DA6')
axs[1,0].plot(ts3, s3[:,13], color='#3B7DA6')
axs[0,0].set_title('EcoG', fontsize=16)
axs[1,0].set_xlabel('seconds [s]')
axs[0,1].plot(ts3, s3[:,14], color='#3B7DA6')
axs[1,1].plot(ts3, s3[:,15], color='#3B7DA6')
axs[0,1].set_title('EMG', fontsize=16)
axs[1,1].set_xlabel('seconds [s]')
plt.tight_layout() 
plt.show()

# plot the frequency components
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s3[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s3[:,j*4+i]), ts3[1] - ts3[0])

        axs[i, j].semilogx(freqs, P, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Power Spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s3[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s3[:,j*4+i]), ts3[1] - ts3[0])
    axs.T.flatten()[i].semilogx(freqs, P, color='#3B7DA6')
axs[0,0].set_title('Power Spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Power Spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()'''

# log scale 
fig, axs = plt.subplots(4, 3, figsize=(15, 7), sharey='col', sharex=True)
for j in range(3):
    for i in range(4):
        fft = np.fft.fft(s3[:,j*4+i])
        P = np.abs(fft) ** 2
        P_db = 10 * np.log10(P)
        freqs = np.fft.fftfreq(len(s3[:,j*4+i]), ts3[1] - ts3[0])

        axs[i, j].semilogx(freqs, P_db, color='#3B7DA6')
        if i == 0:
            axs[i,j].set_title(f'Tetrode {j+1}', color='#65A4DC')
        if i == 3:
            axs[i, j].set_xlabel('frequency [Hz]')
plt.suptitle('Log scale power spectrum (LFP/AP channels)', fontsize=16)
plt.tight_layout() 
plt.show()

fig, axs = plt.subplots(2, 2, figsize=(15, 7), sharey='col', sharex=True)
vec = [12,13,14,15]
for i in range(len(vec)):
    fft = np.fft.fft(s3[:,vec[i]])
    P = np.abs(fft) ** 2
    P_db = 10 * np.log10(P)
    freqs = np.fft.fftfreq(len(s3[:,j*4+i]), ts3[1] - ts3[0])
    axs.T.flatten()[i].semilogx(freqs, P_db, color='#3B7DA6')
axs[0,0].set_title('Log scale power spectrum (EcoG)', fontsize=16)
axs[1,0].set_xlabel('frequency [Hz]')
axs[0,1].set_title('Log scale power spectrum (EMG)', fontsize=16)
axs[1,1].set_xlabel('frequency [Hz]')
plt.tight_layout() 
plt.show()
